# %% [markdown]
# # UniAssist – Data Exploration Notebook
#
# ## Purpose
# This notebook is used to understand and verify the UniAssist
# question–answer dataset before building any intelligent system.
#
# No machine learning models are trained here.
# The goal is only to study the data clearly and safely.

# %% [markdown]
# # Stage 1

# %%
import os
os.listdir()
# Out:
# ['.config', 'UniAssist_training_data.csv', 'sample_data']

# %%
import pandas as pd
import numpy as np

# %%
DATASET_PATH = "UniAssist_training_data.csv"
qa_frame = pd.read_csv(DATASET_PATH)

# %%
qa_frame.head()
# Out:
#    category_id                       category_name intent_id  \
# 0            1  Attendance and Academic Compliance     C1_Q1
# 1            1  Attendance and Academic Compliance     C1_Q1
# 2            1  Attendance and Academic Compliance     C1_Q1
# 3            1  Attendance and Academic Compliance     C1_Q1
# 4            1  Attendance and Academic Compliance     C1_Q1
#
#                                             question  \
# 0        What is the minimum attendance requirement?
# 1  What percentage of attendance is required to c...
# 2  Is there a minimum attendance criteria for stu...
# 3   How much attendance is compulsory in a semester?
# 4  What is the required attendance percentage for...
#
#                                               answer
# 0  Students are required to maintain a minimum of...
# 1  Students are required to maintain a minimum of...
# 2  Students are required to maintain a minimum of...
# 3  Students are required to maintain a minimum of...
# ...

# %%
qa_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1075 entries, 0 to 1074
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   category_id    1075 non-null   int64
#  1   category_name  1075 non-null   object
#  2   intent_id      1075 non-null   object
#  3   question       1075 non-null   object
#  4   answer         1075 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 42.1+ KB

# %%
qa_frame.columns.tolist()
# Out:
# ['category_id', 'category_name', 'intent_id', 'question', 'answer']

# %%
qa_frame.shape
# Out:
# (1075, 5)

# %%
qa_frame["question_length"] = qa_frame["question"].astype(str).apply(len)
qa_frame["answer_length"] = qa_frame["answer"].astype(str).apply(len)

# %%
qa_frame[["question_length", "answer_length"]].describe()
# Out:
#        question_length  answer_length
# count      1075.000000    1075.000000
# mean         42.804651     126.249302
# std          11.303786      32.129208
# min           2.000000      50.000000
# 25%          38.000000     111.000000
# 50%          45.000000     125.000000
# 75%          50.000000     136.000000
# max          72.000000     251.000000

# %% [markdown]
# ## Observations
#
# - The dataset contains academic and internship-related questions.
# - Answers are factual and concise.
# - The dataset size is suitable for retrieval-based systems.
# - This data will act as the single source of truth for UniAssist.
